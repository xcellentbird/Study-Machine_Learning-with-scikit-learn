# %% [markdown]
# <a href="https://colab.research.google.com/github/xcellentbird/Machine_Learning/blob/main/3%EB%B6%84_torch_ResNet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torchvision import transforms, datasets, models

# %%
CUDA = torch.cuda.is_available()
DEVICE = torch.device('cuda' if CUDA else 'cpu')
print(DEVICE)
# Out:
# cuda

# %%
epochs = 300
batch_size = 128

# %%
Normalizer = transforms.Normalize((0.5,0.5,0.5), (0.5,0.5,0.5))
train_data_transform = transforms.Compose([
                                           transforms.RandomCrop(32, padding=4),
                                           transforms.RandomHorizontalFlip(),
                                           transforms.ToTensor(),
                                           Normalizer
])
test_data_transform = transforms.Compose([
                                          transforms.ToTensor(),
                                          Normalizer
])

# %%
train_datasets = datasets.CIFAR10('./', train=True, download=True, transform=train_data_transform)
test_datasets = datasets.CIFAR10('./', train=False, transform=test_data_transform)
# Out:
# Files already downloaded and verified

# %%
train_loader = torch.utils.data.DataLoader(train_datasets, batch_size=batch_size, shuffle=True)
test_loader = torch.utils.data.DataLoader(test_datasets, batch_size=batch_size, shuffle=False)

# %%
class BasicBlock(nn.Module):
  def __init__(self, in_planes, planes, stride=1):
    super(BasicBlock, self).__init__()
    # 정상 루트
    self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=3,
                           stride=stride, padding=1, bias=False)
    self.bn1 = nn.BatchNorm2d(planes)
    self.conv2 = nn.Conv2d(planes, planes, kernel_size=3,
                           stride=1, padding=1, bias=False)
    self.bn2 = nn.BatchNorm2d(planes)
    
    # 지름길 루트
    # 입력값이 정상 루트를 거치면서 크기가 변한다면,
    # 지름길 루트도 똑같이 크기를 변환
    self.shortcut = nn.Sequential()
    if stride != 1 or in_planes != planes:
      self.shortcut = nn.Sequential(
          nn.Conv2d(in_planes, planes, kernel_size=1, stride=stride, bias=False),
          nn.BatchNorm2d(planes)
        )

  def forward(self, x):
    # 정상 루트
    out = self.conv1(x)
    out = self.bn1(out)
    out = F.relu(out)
    out = self.conv2(out)
    out = self.bn2(out)

    # 정상 루트와 지름길 루트 결과값을 더한다.
    out += self.shortcut(x)
    out = F.relu(out)
    return out

# %%
class ResNet(nn.Module):
  def __init__(self, num_classes = 10):
    super(ResNet, self).__init__()
    self.in_planes = 16

    self.conv1 = nn.Conv2d(3, 16, kernel_size=3, stride=1, padding=1, bias=False)
    self.bn1 = nn.BatchNorm2d(16)
    self.layer1 = self._make_layer(16, 2, stride=1)
    self.layer2 = self._make_layer(32, 2, stride=2)
    self.layer3 = self._make_layer(64, 2, stride=2)
    self.linear = nn.Linear(64, num_classes)

  def _make_layer(self, planes, num_blocks, stride):
    strides = [stride] + [1]*(num_blocks-1)
    layers = []
    for stride in strides:
      layers.append(BasicBlock(self.in_planes, planes, stride))
      self.in_planes = planes
    return nn.Sequential(*layers)

  def forward(self, x):
    out = self.conv1(x)
    out = self.bn1(out)
    out = F.relu(out)
    out = self.layer1(out)
    out = self.layer2(out)
    out = self.layer3(out)
    out = F.avg_pool2d(out, 8)
    out = out.view(out.size(0), -1)
    out = self.linear(out)
    return out

# %%
model = ResNet().to(DEVICE)
optimizer = optim.SGD(model.parameters(), lr=0.1,
                      momentum=0.9, weight_decay=0.0005)
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=50, gamma=0.1)

# %%
def train(model, train_loader, optimizer, epoch):
  model.train()
  for idx, (data, target) in enumerate(train_loader):
    data, target = data.to(DEVICE), target.to(DEVICE)
    optimizer.zero_grad()
    output = model(data)
    loss = F.cross_entropy(output, target)
    loss.backward()
    optimizer.step()

# %%
def evaluate(model, test_loader):
  model.eval()
  test_loss = 0
  correct = 0
  with torch.no_grad():
    for data, target in test_loader:
      data, target = data.to(DEVICE), target.to(DEVICE)
      output = model(data)

      test_loss += F.cross_entropy(output, target, reduction='sum').item()

      prob, pred = output.max(1, keepdim=True)
      correct += pred.eq(target.view_as(pred)).sum().item()

  test_loss /= len(test_loader.dataset)
  test_accuracy = 100. * correct / len(test_loader.dataset)
  return test_loss, test_accuracy

# %%
for epoch in range(epochs):
  train(model, train_loader, optimizer, epoch+1)
  test_loss, test_accuracy = evaluate(model, test_loader)
  
  print('[{}] Test Loss: {:.4f}, Accuracy: {:.2f}%'.format(epoch+1, test_loss, test_accuracy))

  scheduler.step()
# Out:
# [1] Test Loss: 1.4996, Accuracy: 46.78%
# [2] Test Loss: 1.3402, Accuracy: 55.13%
# [3] Test Loss: 1.1250, Accuracy: 61.63%
# [4] Test Loss: 0.8831, Accuracy: 68.31%
# [5] Test Loss: 0.8326, Accuracy: 71.17%
# [6] Test Loss: 0.8082, Accuracy: 73.13%
# [7] Test Loss: 0.8800, Accuracy: 71.68%
# [8] Test Loss: 0.8522, Accuracy: 72.91%
# [9] Test Loss: 0.7987, Accuracy: 72.69%
# [10] Test Loss: 0.7695, Accuracy: 74.37%
# [11] Test Loss: 0.7744, Accuracy: 75.43%
# [12] Test Loss: 0.8132, Accuracy: 74.50%
# [13] Test Loss: 0.7101, Accuracy: 76.06%
# [14] Test Loss: 0.7883, Accuracy: 74.33%
# [15] Test Loss: 0.7531, Accuracy: 75.54%
# [16] Test Loss: 0.6600, Accuracy: 77.48%
# [17] Test Loss: 0.6831, Accuracy: 77.35%
# [18] Test Loss: 0.6473, Accuracy: 78.63%
# [19] Test Loss: 0.7923, Accuracy: 73.18%
# [20] Test Loss: 0.8168, Accuracy: 74.49%
# [21] Test Loss: 0.7149, Accuracy: 76.11%
# [22] Test Loss: 0.8015, Accuracy: 73.68%
# [23] Test Loss: 0.8945, Accuracy: 73.12%
# [24] Test Loss: 0.6868, Accuracy: 78.15%
# [25] Test Loss: 0.8050, Accuracy: 74.11%
# [26] Test Loss: 0.8625, Accuracy: 72.85%
# [27] Test Loss: 0.8577, Accuracy: 72.63%
# [28] Test Loss: 0.6055, Accuracy: 79.87%
# [29] Test Loss: 0.7657, Accuracy: 75.15%
# [30] Test Loss: 0.8159, Accuracy: 72.47%
# [31] Test Loss: 0.5894, Accuracy: 80.00%
# [32] Test Loss: 0.7836, Accuracy: 75.52%
# [33] Test Loss: 0.6411, Accuracy: 78.34%
# [34] Test Loss: 0.7651, Accuracy: 74.46%
# [35] Test Loss: 0.5712, Accuracy: 80.40%
# [36] Test Loss: 0.9261, Accuracy: 71.64%
# [37] Test Loss: 0.9075, Accuracy: 71.68%
# [38] Test Loss: 0.6627, Accuracy: 78.54%
# [39] Test Loss: 0.7942, Accuracy: 75.54%
# [40] Test Loss: 0.5954, Accuracy: 79.78%
# [41] Test Loss: 0.8029, Accuracy: 75.07%
# [42] Test Loss: 0.6757, Accuracy: 77.97%
# [43] Test Loss: 0.6992, Accuracy: 77.53%
# [44] Test Loss: 0.7534, Accuracy: 74.52%
# [45] Test Loss: 0.9161, Accuracy: 74.47%
# [46] Test Loss: 0.6717, Accuracy: 78.36%
# [47] Test Loss: 0.5582, Accuracy: 81.72%
# [48] Test Loss: 0.7878, Accuracy: 74.65%
# [49] Test Loss: 1.2918, Accuracy: 66.11%
# [50] Test Loss: 0.8291, Accuracy: 73.73%
# [51] Test Loss: 0.3456, Accuracy: 88.37%
# [52] Test Loss: 0.3300, Accuracy: 89.00%
# [53] Test Loss: 0.3265, Accuracy: 88.92%
# [54] Test Loss: 0.3236, Accuracy: 89.14%
# [55] Test Loss: 0.3297, Accuracy: 88.73%
# [56] Test Loss: 0.3208, Accuracy: 89.16%
# [57] Test Loss: 0.3136, Accuracy: 89.75%
# [58] Test Loss: 0.3115, Accuracy: 89.61%
# [59] Test Loss: 0.3167, Accuracy: 89.18%
# [60] Test Loss: 0.3208, Accuracy: 88.87%
# [61] Test Loss: 0.3131, Accuracy: 89.37%
# [62] Test Loss: 0.3067, Accuracy: 89.54%
# [63] Test Loss: 0.3192, Accuracy: 89.35%
# [64] Test Loss: 0.3316, Accuracy: 89.11%
# [65] Test Loss: 0.3209, Accuracy: 89.18%
# [66] Test Loss: 0.3439, Accuracy: 88.88%
# [67] Test Loss: 0.3254, Accuracy: 89.06%
# [68] Test Loss: 0.3385, Accuracy: 89.07%
# [69] Test Loss: 0.3733, Accuracy: 88.29%
# [70] Test Loss: 0.3447, Accuracy: 88.67%
# [71] Test Loss: 0.3449, Accuracy: 88.80%
# [72] Test Loss: 0.3495, Accuracy: 89.08%
# [73] Test Loss: 0.3418, Accuracy: 89.06%
# [74] Test Loss: 0.3406, Accuracy: 88.69%
# [75] Test Loss: 0.4020, Accuracy: 87.38%
# [76] Test Loss: 0.3468, Accuracy: 88.67%
# [77] Test Loss: 0.3525, Accuracy: 88.47%
# [78] Test Loss: 0.3613, Accuracy: 88.19%
# [79] Test Loss: 0.3645, Accuracy: 88.27%
# [80] Test Loss: 0.3664, Accuracy: 88.11%
# [81] Test Loss: 0.3476, Accuracy: 88.57%
# [82] Test Loss: 0.3611, Accuracy: 88.48%
# [83] Test Loss: 0.3986, Accuracy: 87.32%
# [84] Test Loss: 0.3455, Accuracy: 88.95%
# [85] Test Loss: 0.3669, Accuracy: 88.28%
# [86] Test Loss: 0.3767, Accuracy: 87.79%
# [87] Test Loss: 0.3557, Accuracy: 88.68%
# [88] Test Loss: 0.3740, Accuracy: 88.09%
# [89] Test Loss: 0.3668, Accuracy: 88.43%
# [90] Test Loss: 0.3631, Accuracy: 88.37%
# [91] Test Loss: 0.3579, Accuracy: 88.46%
# [92] Test Loss: 0.3458, Accuracy: 88.68%
# [93] Test Loss: 0.4020, Accuracy: 87.18%
# [94] Test Loss: 0.4090, Accuracy: 87.21%
# [95] Test Loss: 0.3552, Accuracy: 88.67%
# [96] Test Loss: 0.4032, Accuracy: 87.56%
# [97] Test Loss: 0.4061, Accuracy: 87.13%
# [98] Test Loss: 0.3672, Accuracy: 88.32%
# [99] Test Loss: 0.3894, Accuracy: 87.81%
# [100] Test Loss: 0.3928, Accuracy: 87.72%
# [101] Test Loss: 0.2887, Accuracy: 90.73%
# [102] Test Loss: 0.2874, Accuracy: 90.91%
# [103] Test Loss: 0.2821, Accuracy: 91.19%
# [104] Test Loss: 0.2824, Accuracy: 90.94%
# [105] Test Loss: 0.2841, Accuracy: 90.98%
# [106] Test Loss: 0.2826, Accuracy: 91.03%
# [107] Test Loss: 0.2803, Accuracy: 91.05%
# [108] Test Loss: 0.2823, Accuracy: 91.01%
# [109] Test Loss: 0.2823, Accuracy: 91.13%
# [110] Test Loss: 0.2815, Accuracy: 91.08%
# [111] Test Loss: 0.2826, Accuracy: 91.11%
# [112] Test Loss: 0.2822, Accuracy: 91.12%
# [113] Test Loss: 0.2814, Accuracy: 91.14%
# [114] Test Loss: 0.2843, Accuracy: 91.17%
# [115] Test Loss: 0.2862, Accuracy: 91.09%
# [116] Test Loss: 0.2854, Accuracy: 91.04%
# [117] Test Loss: 0.2832, Accuracy: 91.14%
# [118] Test Loss: 0.2858, Accuracy: 91.01%
# [119] Test Loss: 0.2846, Accuracy: 91.15%
# [120] Test Loss: 0.2857, Accuracy: 91.06%
# [121] Test Loss: 0.2875, Accuracy: 91.08%
# [122] Test Loss: 0.2882, Accuracy: 91.13%
# [123] Test Loss: 0.2904, Accuracy: 90.97%
# [124] Test Loss: 0.2908, Accuracy: 90.97%
# [125] Test Loss: 0.2930, Accuracy: 91.04%
# [126] Test Loss: 0.2973, Accuracy: 91.03%
# [127] Test Loss: 0.2941, Accuracy: 90.82%
# [128] Test Loss: 0.2942, Accuracy: 90.99%
# [129] Test Loss: 0.2943, Accuracy: 91.05%
# [130] Test Loss: 0.2918, Accuracy: 91.16%
# [131] Test Loss: 0.2971, Accuracy: 90.91%
# [132] Test Loss: 0.2953, Accuracy: 91.12%
# [133] Test Loss: 0.2963, Accuracy: 91.06%
# [134] Test Loss: 0.2949, Accuracy: 90.85%
# [135] Test Loss: 0.2944, Accuracy: 91.15%
# [136] Test Loss: 0.2990, Accuracy: 90.78%
# [137] Test Loss: 0.3016, Accuracy: 90.88%
# [138] Test Loss: 0.3013, Accuracy: 90.82%
# [139] Test Loss: 0.3001, Accuracy: 90.90%
# [140] Test Loss: 0.2976, Accuracy: 90.95%
# [141] Test Loss: 0.3018, Accuracy: 91.07%
# [142] Test Loss: 0.2975, Accuracy: 90.95%
# [143] Test Loss: 0.3006, Accuracy: 90.96%
# [144] Test Loss: 0.3039, Accuracy: 90.94%
# [145] Test Loss: 0.3067, Accuracy: 90.68%
# [146] Test Loss: 0.3044, Accuracy: 90.76%
# [147] Test Loss: 0.3091, Accuracy: 90.86%
# [148] Test Loss: 0.3047, Accuracy: 90.99%
# [149] Test Loss: 0.3127, Accuracy: 90.94%
# [150] Test Loss: 0.3050, Accuracy: 91.11%
# [151] Test Loss: 0.3043, Accuracy: 91.04%
# [152] Test Loss: 0.3040, Accuracy: 91.09%
# [153] Test Loss: 0.3064, Accuracy: 91.09%
# [154] Test Loss: 0.3028, Accuracy: 91.24%
# [155] Test Loss: 0.3035, Accuracy: 91.04%
# [156] Test Loss: 0.3028, Accuracy: 91.12%
# [157] Test Loss: 0.3020, Accuracy: 91.12%
# [158] Test Loss: 0.3041, Accuracy: 91.07%
# [159] Test Loss: 0.3056, Accuracy: 91.09%
# [160] Test Loss: 0.3019, Accuracy: 91.16%
# [161] Test Loss: 0.3035, Accuracy: 91.07%
# [162] Test Loss: 0.3032, Accuracy: 91.02%
# [163] Test Loss: 0.3012, Accuracy: 91.03%
# [164] Test Loss: 0.3040, Accuracy: 91.05%
# [165] Test Loss: 0.3035, Accuracy: 91.00%
# [166] Test Loss: 0.3030, Accuracy: 91.06%
# [167] Test Loss: 0.3019, Accuracy: 91.09%
# [168] Test Loss: 0.3027, Accuracy: 91.07%
# [169] Test Loss: 0.3049, Accuracy: 91.01%
# [170] Test Loss: 0.3035, Accuracy: 91.05%
# [171] Test Loss: 0.3051, Accuracy: 91.14%
# [172] Test Loss: 0.3046, Accuracy: 90.94%
# [173] Test Loss: 0.3061, Accuracy: 90.97%
# [174] Test Loss: 0.3064, Accuracy: 91.10%
# [175] Test Loss: 0.3024, Accuracy: 91.11%
# [176] Test Loss: 0.3047, Accuracy: 90.93%
# [177] Test Loss: 0.3053, Accuracy: 91.06%
# [178] Test Loss: 0.3053, Accuracy: 91.04%
# [179] Test Loss: 0.3051, Accuracy: 90.98%
# [180] Test Loss: 0.3056, Accuracy: 91.00%
# [181] Test Loss: 0.3050, Accuracy: 90.90%
# [182] Test Loss: 0.3034, Accuracy: 90.96%
# [183] Test Loss: 0.3053, Accuracy: 90.82%
# [184] Test Loss: 0.3053, Accuracy: 91.00%
# [185] Test Loss: 0.3048, Accuracy: 91.07%
# [186] Test Loss: 0.3049, Accuracy: 91.08%
# [187] Test Loss: 0.3056, Accuracy: 90.98%
# [188] Test Loss: 0.3084, Accuracy: 91.00%
# [189] Test Loss: 0.3078, Accuracy: 90.90%
# [190] Test Loss: 0.3073, Accuracy: 90.85%
# [191] Test Loss: 0.3061, Accuracy: 90.90%
# [192] Test Loss: 0.3068, Accuracy: 91.03%
# [193] Test Loss: 0.3072, Accuracy: 91.03%
# [194] Test Loss: 0.3070, Accuracy: 90.96%
# [195] Test Loss: 0.3062, Accuracy: 90.97%
# [196] Test Loss: 0.3061, Accuracy: 90.89%
# [197] Test Loss: 0.3088, Accuracy: 91.06%
# [198] Test Loss: 0.3058, Accuracy: 90.89%
# [199] Test Loss: 0.3055, Accuracy: 91.08%
# [200] Test Loss: 0.3075, Accuracy: 91.02%
# [201] Test Loss: 0.3086, Accuracy: 90.89%
# [202] Test Loss: 0.3087, Accuracy: 90.95%
# [203] Test Loss: 0.3076, Accuracy: 90.89%
# [204] Test Loss: 0.3075, Accuracy: 90.99%
# [205] Test Loss: 0.3093, Accuracy: 90.84%
# [206] Test Loss: 0.3068, Accuracy: 90.98%
# [207] Test Loss: 0.3078, Accuracy: 90.98%
# [208] Test Loss: 0.3057, Accuracy: 91.02%
# [209] Test Loss: 0.3071, Accuracy: 91.00%
# [210] Test Loss: 0.3038, Accuracy: 90.98%
# [211] Test Loss: 0.3065, Accuracy: 91.01%
# [212] Test Loss: 0.3048, Accuracy: 90.94%
# [213] Test Loss: 0.3055, Accuracy: 91.00%
# [214] Test Loss: 0.3079, Accuracy: 90.94%
# [215] Test Loss: 0.3059, Accuracy: 91.09%
# [216] Test Loss: 0.3088, Accuracy: 90.92%
# [217] Test Loss: 0.3051, Accuracy: 90.91%
# [218] Test Loss: 0.3073, Accuracy: 90.92%
# [219] Test Loss: 0.3059, Accuracy: 90.94%
# [220] Test Loss: 0.3057, Accuracy: 90.86%
# [221] Test Loss: 0.3071, Accuracy: 91.06%
# [222] Test Loss: 0.3075, Accuracy: 91.01%
# [223] Test Loss: 0.3068, Accuracy: 91.00%
# [224] Test Loss: 0.3070, Accuracy: 91.01%
# [225] Test Loss: 0.3096, Accuracy: 91.05%
# [226] Test Loss: 0.3077, Accuracy: 91.01%
# [227] Test Loss: 0.3056, Accuracy: 91.15%
# [228] Test Loss: 0.3064, Accuracy: 90.90%
# [229] Test Loss: 0.3081, Accuracy: 90.81%
# [230] Test Loss: 0.3061, Accuracy: 91.09%
# [231] Test Loss: 0.3036, Accuracy: 91.04%
# [232] Test Loss: 0.3055, Accuracy: 91.03%
# [233] Test Loss: 0.3069, Accuracy: 90.98%
# [234] Test Loss: 0.3069, Accuracy: 90.91%
# [235] Test Loss: 0.3087, Accuracy: 90.93%
# [236] Test Loss: 0.3068, Accuracy: 91.16%
# [237] Test Loss: 0.3076, Accuracy: 91.03%
# [238] Test Loss: 0.3066, Accuracy: 90.91%
# [239] Test Loss: 0.3059, Accuracy: 90.97%
# [240] Test Loss: 0.3052, Accuracy: 91.04%
# [241] Test Loss: 0.3054, Accuracy: 90.95%
# [242] Test Loss: 0.3081, Accuracy: 91.11%
# [243] Test Loss: 0.3044, Accuracy: 90.94%
# [244] Test Loss: 0.3070, Accuracy: 91.03%
# [245] Test Loss: 0.3097, Accuracy: 90.96%
# [246] Test Loss: 0.3072, Accuracy: 90.88%
# [247] Test Loss: 0.3078, Accuracy: 90.95%
# [248] Test Loss: 0.3071, Accuracy: 91.11%
# [249] Test Loss: 0.3055, Accuracy: 90.99%
# [250] Test Loss: 0.3088, Accuracy: 91.11%
# [251] Test Loss: 0.3092, Accuracy: 90.93%
# [252] Test Loss: 0.3049, Accuracy: 90.98%
# [253] Test Loss: 0.3065, Accuracy: 90.94%
# [254] Test Loss: 0.3064, Accuracy: 91.00%
# [255] Test Loss: 0.3068, Accuracy: 90.99%
# [256] Test Loss: 0.3071, Accuracy: 91.08%
# [257] Test Loss: 0.3060, Accuracy: 91.02%
# [258] Test Loss: 0.3071, Accuracy: 90.96%
# [259] Test Loss: 0.3054, Accuracy: 91.00%
# [260] Test Loss: 0.3069, Accuracy: 90.99%
# [261] Test Loss: 0.3084, Accuracy: 91.08%
# [262] Test Loss: 0.3070, Accuracy: 90.95%
# [263] Test Loss: 0.3053, Accuracy: 91.01%
# [264] Test Loss: 0.3068, Accuracy: 91.01%
# [265] Test Loss: 0.3044, Accuracy: 90.88%
# [266] Test Loss: 0.3064, Accuracy: 91.02%
# [267] Test Loss: 0.3056, Accuracy: 91.01%
# [268] Test Loss: 0.3076, Accuracy: 91.02%
# [269] Test Loss: 0.3049, Accuracy: 90.93%
# [270] Test Loss: 0.3059, Accuracy: 90.96%
# [271] Test Loss: 0.3058, Accuracy: 91.06%
# [272] Test Loss: 0.3079, Accuracy: 91.00%
# [273] Test Loss: 0.3071, Accuracy: 90.98%
# [274] Test Loss: 0.3083, Accuracy: 90.90%
# [275] Test Loss: 0.3075, Accuracy: 90.89%
# [276] Test Loss: 0.3063, Accuracy: 90.95%
# [277] Test Loss: 0.3061, Accuracy: 90.98%
# [278] Test Loss: 0.3059, Accuracy: 91.01%
# [279] Test Loss: 0.3044, Accuracy: 91.05%
# [280] Test Loss: 0.3069, Accuracy: 90.96%
# [281] Test Loss: 0.3062, Accuracy: 91.14%
# [282] Test Loss: 0.3049, Accuracy: 90.95%
# [283] Test Loss: 0.3063, Accuracy: 90.87%
# [284] Test Loss: 0.3071, Accuracy: 90.91%
# [285] Test Loss: 0.3074, Accuracy: 90.92%
# [286] Test Loss: 0.3065, Accuracy: 91.16%
# [287] Test Loss: 0.3066, Accuracy: 91.01%
# [288] Test Loss: 0.3071, Accuracy: 90.96%
# [289] Test Loss: 0.3056, Accuracy: 91.01%
# [290] Test Loss: 0.3066, Accuracy: 91.03%
# [291] Test Loss: 0.3068, Accuracy: 91.15%
# [292] Test Loss: 0.3054, Accuracy: 90.91%
# [293] Test Loss: 0.3075, Accuracy: 91.05%
# [294] Test Loss: 0.3040, Accuracy: 90.94%
# [295] Test Loss: 0.3049, Accuracy: 91.01%
# [296] Test Loss: 0.3049, Accuracy: 90.97%
# [297] Test Loss: 0.3084, Accuracy: 90.95%
# [298] Test Loss: 0.3061, Accuracy: 91.07%
# [299] Test Loss: 0.3054, Accuracy: 90.95%
# [300] Test Loss: 0.3065, Accuracy: 90.95%
